# %%
import pandas as pd
from pathlib import Path
import xarray as xr
import numpy as np
import calendar
import os.path

import matplotlib.pyplot as plt

# %%
ds = xr.open_dataset('/home/jovyan/shared/jiarui-notebooks/predicted_sst_data_2023-09-04.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 401, lon: 451)
# Coordinates:
#   * lat      (lat) float64 -5.0 -4.9 -4.8 -4.7 -4.6 ... 34.6 34.7 34.8 34.9 35.0
#   * lon      (lon) float64 45.0 45.1 45.2 45.3 45.4 ... 89.6 89.7 89.8 89.9 90.0
# Data variables:
#     sst      (lat, lon) float32 ...

# %%
analysed_sst = ds['sst']

analysed_sst.plot()

plt.show()
